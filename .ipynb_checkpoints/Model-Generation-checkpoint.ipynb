# %%
import pandas as pd

# %%
df=pd.read_csv('realistic_medical_data.csv')
df.head()
# Out:
#    Heart Rate  Systolic BP  Diastolic BP  Temperature Health Status
# 0   74.967142   109.872326     60.921924    37.699678          Risk
# 1   68.617357   117.832220     71.396150    37.462317       Healthy
# 2   76.476885   108.113701     75.863945    37.029815          Risk
# 3   85.230299   125.380577    103.876877    37.176532      Critical
# 4   67.658466    91.595780     85.565531    37.349112          Risk

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Heart Rate     1000 non-null   float64
#  1   Systolic BP    1000 non-null   float64
#  2   Diastolic BP   1000 non-null   float64
#  3   Temperature    1000 non-null   float64
#  4   Health Status  1000 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
df.isna().sum()
# Out:
# Heart Rate       0
# Systolic BP      0
# Diastolic BP     0
# Temperature      0
# Health Status    0
# dtype: int64

# %%
df.describe()
# Out:
#         Heart Rate  Systolic BP  Diastolic BP  Temperature
# count  1000.000000  1000.000000   1000.000000  1000.000000
# mean     70.246392   120.302882     79.944927    37.039418
# std       9.663995    15.604347     10.337598     0.558265
# min      50.000000    90.000000     60.000000    35.204479
# 25%      63.524097   109.894717     72.620872    36.687891
# 50%      70.253006   119.597570     79.950137    37.034477
# 75%      76.479439   130.608379     87.124196    37.410334
# max     108.527315   178.893566    112.430930    38.779100

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Heart Rate'}>,
#         <Axes: title={'center': 'Systolic BP'}>],
#        [<Axes: title={'center': 'Diastolic BP'}>,
#         <Axes: title={'center': 'Temperature'}>]], dtype=object)

# %%
df['Health Status'].value_counts()
# Out:
# Health Status
# Risk        459
# Critical    404
# Healthy     137
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() 
  
# Encode labels in column 'species'. 
df['health_status_transformed']= le.fit_transform(df['Health Status']) 
  
df.head()
# Out:
#    Heart Rate  Systolic BP  Diastolic BP  Temperature Health Status  \
# 0   74.967142   109.872326     60.921924    37.699678          Risk
# 1   68.617357   117.832220     71.396150    37.462317       Healthy
# 2   76.476885   108.113701     75.863945    37.029815          Risk
# 3   85.230299   125.380577    103.876877    37.176532      Critical
# 4   67.658466    91.595780     85.565531    37.349112          Risk
#
#    health_status_transformed
# 0                          2
# 1                          1
# 2                          2
# 3                          0
# 4                          2

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)
# Out:
# {'Critical': 0, 'Healthy': 1, 'Risk': 2}

# %%
new_df=df.drop(['Health Status'],axis=1)

# %%
new_df.corr()
# Out:
#                            Heart Rate  Systolic BP  Diastolic BP  Temperature  \
# Heart Rate                   1.000000     0.320585      0.210920     0.386315
# Systolic BP                  0.320585     1.000000      0.108220     0.164002
# Diastolic BP                 0.210920     0.108220      1.000000     0.053212
# Temperature                  0.386315     0.164002      0.053212     1.000000
# health_status_transformed    0.187457    -0.176760     -0.347213     0.132633
#
#                            health_status_transformed
# Heart Rate                                  0.187457
# Systolic BP                                -0.176760
# Diastolic BP                               -0.347213
# Temperature                                 0.132633
# health_status_transformed                   1.000000

# %%
df.drop(['health_status_transformed'],axis=1,inplace=True)

# %%
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
sns.pairplot(data=df,hue='Health Status')
# plt.legend()
plt.show()

# %%
x=df.drop(['Health Status'],axis=1)
x.head()
# Out:
#    Heart Rate  Systolic BP  Diastolic BP  Temperature
# 0   74.967142   109.872326     60.921924    37.699678
# 1   68.617357   117.832220     71.396150    37.462317
# 2   76.476885   108.113701     75.863945    37.029815
# 3   85.230299   125.380577    103.876877    37.176532
# 4   67.658466    91.595780     85.565531    37.349112

# %%
y=df['Health Status']
y.head()
# Out:
# 0        Risk
# 1     Healthy
# 2        Risk
# 3    Critical
# 4        Risk
# Name: Health Status, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.98

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[82,  0,  1],
#        [ 0, 24,  2],
#        [ 1,  0, 90]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Critical       0.99      0.99      0.99        83
#      Healthy       1.00      0.92      0.96        26
#         Risk       0.97      0.99      0.98        91
#
#     accuracy                           0.98       200
#    macro avg       0.99      0.97      0.98       200
# weighted avg       0.98      0.98      0.98       200

# %%
import joblib

# %%
from joblib import Parallel, delayed 
import joblib 
  
  
# Save the model as a pickle in a file 
# joblib.dump(model, 'model.pkl') 
  
# Load the model from the file 
modelx = joblib.load('model.pkl') 
  
# Use the loaded model to make predictions 
modelx.predict([[65,120,80,37]])
# Out:
# C:\Users\PS001028870\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Healthy'], dtype=object)
